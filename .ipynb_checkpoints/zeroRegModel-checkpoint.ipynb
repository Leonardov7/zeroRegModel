# %% [markdown]
# ## Modelo predictivo para elección de participantes de matrícula cero

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../Data/Reporte_general__Caracterizacion__novedades_y_requisitos_politica_de_gratuidad__para_las_IES__7.csv',sep=';', encoding='latin1')

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#     AÑO  SEMESTRE  ID_PARTICIPANTE TIPO_DOCUMENTO  NUM_DOCUMENTO  \
# 0  2024         1         10901473             CC     1003540649
# 1  2024         1         12650551             TI     1034658741
# 2  2024         1         12650552             CC     1016001018
# 3  2024         1         12650554             CC     1003614541
# 4  2024         1         12650557             CC     1003517580
#
#   OTROS_DOCUMENTOS PRIMER_NOMBRE SEGUNDO_NOMBRE PRIMER_APELLIDO  \
# 0    TI 1003540649       NICOLLE      VALENTINA           GODOY
# 1              NaN          JUAN          DIEGO       RODRIGUEZ
# 2    TI 1016001018         LAURA       GABRIELA         PIÑEROS
# 3    TI 1003614541         KAROL         ANDREA            DAZA
# 4              NaN        MARLON         JEFREY        GONZALEZ
#
#   SEGUNDO_APELLIDO  DESC_SEXO DESC_PAIS_NACIMIENTO DESC_DEPTO_NACIMIENTO  \
# 0             VACA   Femenino             COLOMBIA          Cundinamarca
# ...

# %%
df.shape
# Out:
# (11768, 75)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11768 entries, 0 to 11767
# Data columns (total 75 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   AÑO                             11768 non-null  int64
#  1   SEMESTRE                        11768 non-null  int64
#  2   ID_PARTICIPANTE                 11768 non-null  int64
#  3   TIPO_DOCUMENTO                  11768 non-null  object
#  4   NUM_DOCUMENTO                   11768 non-null  int64
#  5   OTROS_DOCUMENTOS                5142 non-null   object
#  6   PRIMER_NOMBRE                   11768 non-null  object
#  7   SEGUNDO_NOMBRE                  10650 non-null  object
#  8   PRIMER_APELLIDO                 11768 non-null  object
#  9   SEGUNDO_APELLIDO                11717 non-null  object
#  10  DESC_SEXO                       11768 non-null  object
#  11  DESC_PAIS_NACIMIENTO            11768 non-null  object
# ...

# %%
(df['TIPO_DOCUMENTO']).value_counts() #grupos de datos de tipo de documento
# Out:
# CC    10531
# TI     1224
# PT        8
# CE        4
# PS        1
# Name: TIPO_DOCUMENTO, dtype: int64

# %%
#filtrar los datos por columnas tipo object con el fin de saber si se pueden mapear o categorizar
columnsObject=df.select_dtypes(include=['object']).columns
print(columnsObject)
print(len(columnsObject))
# Out:
# Index(['TIPO_DOCUMENTO', 'OTROS_DOCUMENTOS', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'DESC_SEXO',
#        'DESC_PAIS_NACIMIENTO', 'DESC_DEPTO_NACIMIENTO',
#        'DESC_MUNICIPIO_NACIMIENTO', 'MUNICIPIO_PDET_NACIMIENTO',
#        'RURALIDAD_MUNICIPIO_NACIMIENTO', 'NOMBRE_IES', 'CARACTER_IES',
#        'DESC_DEPTO_IES', 'DESC_MUNICIPIO_IES', 'NOMBRE_PROGRAMA',
#        'ES_CICLO_PROPEDEUTICO', 'NIVEL_DE_FORMACION',
#        'ESTUDIANTE_PRIMER_CURSO', 'TIPO_VINCULACION', 'VALIDACION_RNEC',
#        'GRADO_PREVIO', 'PERIODO_APROBACION', 'FONDO_ORIGEN',
#        'PROGRAMA_SEMESTRE_ANTERIOR', 'PROGRAMA_ACTUAL',
#        'COINCIDENCIA_ACADEMICA', 'CAUSAS_NO_ACCESO_IES',
#        'CRITERIO_NO_ACEPTACION', 'CRITERIO_NO_RENOVACION', 'PUNTAJE_SISBEN',
#        'ES_VICTIMA', 'ES_INDIGENA', 'ESTRATO_INGRESO', 'CRITERIO_ACEPTACION',
#        'RESULTADO_VALIDACION', 'CONSISTENCIA_VALOR_MATRICULA',
# ...

# %%
for col in columnsObject:
    print(f"Columna: {col}")
    print("Valores únicos:")
    print(df[col].unique())
    print("\nFrecuencia de valores:")
    print(df[col].value_counts())
    print("\n" + "-"*50 + "\n")
# Out:
# Columna: TIPO_DOCUMENTO
# Valores únicos:
# ['CC' 'TI' 'CE' 'PT' 'PS']
#
# Frecuencia de valores:
# CC    10531
# TI     1224
# PT        8
# CE        4
# PS        1
# Name: TIPO_DOCUMENTO, dtype: int64
#
# --------------------------------------------------
#
# Columna: OTROS_DOCUMENTOS
# Valores únicos:
# ['TI 1003540649' nan 'TI 1016001018' ... 'TI 1069715058' 'TI 1002525854'
#  'TI 1003691236']
#
# Frecuencia de valores:
# TI 1003540649     1
# TI 1193105273     1
# TI 1000128313     1
# TI 98030152670    1
# TI 1111042250     1
#                  ..
# TI 1003690258     1
# TI 1007379180     1
# TI 99120806463    1
# TI 1003519349     1
# TI 1003691236     1
# Name: OTROS_DOCUMENTOS, Length: 5142, dtype: int64
#
# --------------------------------------------------
#
# Columna: PRIMER_NOMBRE
# Valores únicos:
# ['NICOLLE' 'JUAN' 'LAURA' ... 'BRECNY' 'YARITZA' 'SHELLY']
#
# Frecuencia de valores:
# JUAN        735
# LAURA       442
# MARIA       352
# ANDRES      257
# ...

# %%
# Filtrar las columnas de tipo object
columnObject = df.select_dtypes(include=['object'])
conteos = columnObject.apply(lambda x: x.value_counts())
conteos.count()
# Out:
# TIPO_DOCUMENTO                       5
# OTROS_DOCUMENTOS                  5142
# PRIMER_NOMBRE                     1715
# SEGUNDO_NOMBRE                    1047
# PRIMER_APELLIDO                   1478
# SEGUNDO_APELLIDO                  1446
# DESC_SEXO                            2
# DESC_PAIS_NACIMIENTO                 7
# DESC_DEPTO_NACIMIENTO               31
# DESC_MUNICIPIO_NACIMIENTO          462
# MUNICIPIO_PDET_NACIMIENTO            1
# RURALIDAD_MUNICIPIO_NACIMIENTO       4
# NOMBRE_IES                           1
# CARACTER_IES                         1
# DESC_DEPTO_IES                       1
# DESC_MUNICIPIO_IES                   3
# NOMBRE_PROGRAMA                     26
# ES_CICLO_PROPEDEUTICO                1
# NIVEL_DE_FORMACION                   2
# ESTUDIANTE_PRIMER_CURSO              1
# TIPO_VINCULACION                     4
# VALIDACION_RNEC                      3
# GRADO_PREVIO                        54
# PERIODO_APROBACION                  11
# ...

# %%
df.describe()
# Out:
#            AÑO  SEMESTRE  ID_PARTICIPANTE  NUM_DOCUMENTO  \
# count  11768.0   11768.0     1.176800e+04   1.176800e+04
# mean    2024.0       1.0     1.107904e+07   1.022585e+09
# std        0.0       0.0     2.675734e+06   1.357924e+08
# min     2024.0       1.0     1.726100e+04   3.716430e+05
# 25%     2024.0       1.0     1.045927e+07   1.003634e+09
# 50%     2024.0       1.0     1.170970e+07   1.019986e+09
# 75%     2024.0       1.0     1.265077e+07   1.070952e+09
# max     2024.0       1.0     1.391902e+07   1.235254e+09
#
#        ID_MUNICIPIO_NACIMIENTO        ID_IES  IES_PADRE  ID_MUNICIPIO_IES  \
# count             11732.000000  11768.000000    11768.0      11768.000000
# mean              23707.093761   1214.229776     1214.0      25318.780082
# std               13594.451008      0.522355        0.0        117.762340
# min                5001.000000   1214.000000     1214.0      25290.000000
# 25%               11001.000000   1214.000000     1214.0      25290.000000
# ...
